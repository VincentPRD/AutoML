# %%
import automl
data_dest="/info/corpus/ChallengeMachineLearning/data_A/"
modele = automl.AutoML()
modele.fit(data_dest)
modele.eval()
print(modele.predict("/info/corpus/ChallengeMachineLearning/data_A/"))
# Out:
# --- Démarrage AutoML sur data_A ---
#  -> Format des données : DataFrame
# Tâche détectée : classification_multi-label
# Configuration du Preprocessing...
# Entraînement de RandomForest...
# Entraînement de HisGradientBoosting...
#
# --- Résultats de l'évaluation initiale ---
# Modèle: RandomForest         | Score Global: 0.8725 | Détails: [F1_MACRO: 0.905, JACCARD: 0.840]
# Modèle: HisGradientBoosting  | Score Global: 0.8780 | Détails: [F1_MACRO: 0.910, JACCARD: 0.846]
#
# MEILLEUR MODÈLE SÉLECTIONNÉ : HisGradientBoosting (Score initial: 0.8780)
#
# --- Optimisation du meilleur modèle : HisGradientBoosting ---
#
# --- Démarrage de l'optimisation pour le modèle: HisGradientBoosting (50 essais) ---
#   0%|          | 0/50 [00:00<?, ?it/s]
# [W 2025-12-19 14:41:14,946] Trial 0 failed with parameters: {} because of the following error: ValueError('Modèle non géré: HisGradientBoosting (Clas=True)').
# Traceback (most recent call last):
#   File "/info/etu/m1/s2102508/miniconda3/envs/Methodo/lib/python3.13/site-packages/optuna/study/_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#   File "/info/raid-etu/m1/s2102508/M1/Projet_Methodo/AutoML/src/optimization/optimize_unique.py", line 85, in <lambda>
#     lambda trial: self.objective(
#                   ~~~~~~~~~~~~~~^
#         trial, X, y, task_type, target_metric_name, model_name
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ),
#     ^
#   File "/info/raid-etu/m1/s2102508/M1/Projet_Methodo/AutoML/src/optimization/optimize_unique.py", line 41, in objective
#     BaseEstimatorClass = get_base_model_class(model_name, is_classification)
#   File "/info/raid-etu/m1/s2102508/M1/Projet_Methodo/AutoML/src/optimization/optimize_utils.py", line 101, in get_base_model_class
#     raise ValueError(f"Modèle non géré: {model_name} (Clas={is_classification})")
# ValueError: Modèle non géré: HisGradientBoosting (Clas=True)
# [W 2025-12-19 14:41:14,952] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       2 data_dest="/info/corpus/ChallengeMachineLearning/data_A/"
#       3 modele = automl.AutoML()
# ----> 4 modele.fit(data_dest)
#       5 modele.eval()
#       6 print(modele.predict("/info/corpus/ChallengeMachineLearning/data_A/"))
#
# File /info/raid-etu/m1/s2102508/M1/Projet_Methodo/AutoML/src/automl.py:147, in AutoML.fit(self, data_dest)
#     145 print(f"\n--- Optimisation du meilleur modèle : {self.best_model_name} ---")
#     146 optimize = AutoOptimizer()
# --> 147 best_model_name_optimized, best_params = optimize.optimize(
#     148     self.X_train_trans,
#     149     self.y_train,
#     150     self.model_info,
#     151     self.best_model_name
#     152 )
#
# File /info/raid-etu/m1/s2102508/M1/Projet_Methodo/AutoML/src/optimization/optimize_unique.py:84, in AutoOptimizer.optimize(self, X, y, task_info, model_name_to_optimize, n_trials)
#      81 print(f"\n--- Démarrage de l'optimisation pour le modèle: {model_name} ({n_trials} essais) ---")
#      83 study = optuna.create_study(direction='maximize')
# ---> 84 study.optimize(
#      85     lambda trial: self.objective(
#      86         trial, X, y, task_type, target_metric_name, model_name
#      87     ),
#      88     n_trials=n_trials,
#      89     show_progress_bar=True
#      90 )
#      92 best_trial = study.best_trial if study.best_trials else None
#      94 if not best_trial or best_trial.state != optuna.trial.TrialState.COMPLETE:
#
# File ~/miniconda3/envs/Methodo/lib/python3.13/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/miniconda3/envs/Methodo/lib/python3.13/site-packages/optuna/study/_optimize.py:67, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      65 try:
#      66     if n_jobs == 1:
# ---> 67         _optimize_sequential(
#      68             study,
#      69             func,
#      70             n_trials,
#      71             timeout,
#      72             catch,
#      73             callbacks,
#      74             gc_after_trial,
#      75             reseed_sampler_rng=False,
#      76             time_start=None,
#      77             progress_bar=progress_bar,
#      78         )
#      79     else:
#      80         if n_jobs == -1:
#
# File ~/miniconda3/envs/Methodo/lib/python3.13/site-packages/optuna/study/_optimize.py:164, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161         break
#     163 try:
# --> 164     frozen_trial_id = _run_trial(study, func, catch)
#     165 finally:
#     166     # The following line mitigates memory problems that can be occurred in some
#     167     # environments (e.g., services that use computing containers such as GitHub Actions).
#     168     # Please refer to the following PR for further details:
#     169     # https://github.com/optuna/optuna/pull/325.
#     170     if gc_after_trial:
#
# File ~/miniconda3/envs/Methodo/lib/python3.13/site-packages/optuna/study/_optimize.py:262, in _run_trial(study, func, catch)
#     255         assert False, "Should not reach."
#     257 if (
#     258     updated_state == TrialState.FAIL
#     259     and func_err is not None
#     260     and not isinstance(func_err, catch)
#     261 ):
# --> 262     raise func_err
#     263 return trial._trial_id
#
# File ~/miniconda3/envs/Methodo/lib/python3.13/site-packages/optuna/study/_optimize.py:205, in _run_trial(study, func, catch)
#     203 with get_heartbeat_thread(trial._trial_id, study._storage):
#     204     try:
# --> 205         value_or_values = func(trial)
#     206     except exceptions.TrialPruned as e:
#     207         # TODO(mamu): Handle multi-objective cases.
#     208         state = TrialState.PRUNED
#
# File /info/raid-etu/m1/s2102508/M1/Projet_Methodo/AutoML/src/optimization/optimize_unique.py:85, in AutoOptimizer.optimize.<locals>.<lambda>(trial)
#      81 print(f"\n--- Démarrage de l'optimisation pour le modèle: {model_name} ({n_trials} essais) ---")
#      83 study = optuna.create_study(direction='maximize')
#      84 study.optimize(
# ---> 85     lambda trial: self.objective(
#      86         trial, X, y, task_type, target_metric_name, model_name
#      87     ),
#      88     n_trials=n_trials,
#      89     show_progress_bar=True
#      90 )
#      92 best_trial = study.best_trial if study.best_trials else None
#      94 if not best_trial or best_trial.state != optuna.trial.TrialState.COMPLETE:
#
# File /info/raid-etu/m1/s2102508/M1/Projet_Methodo/AutoML/src/optimization/optimize_unique.py:41, in AutoOptimizer.objective(self, trial, X_train, y_train, task_type, target_metric_name, model_name)
#      38 is_classification = "classification" in task_type
#      40 params = suggest_hyperparameters(trial, model_name)
# ---> 41 BaseEstimatorClass = get_base_model_class(model_name, is_classification)
#      43 base_estimator = BaseEstimatorClass(**params)
#      44 model = base_estimator
#
# File /info/raid-etu/m1/s2102508/M1/Projet_Methodo/AutoML/src/optimization/optimize_utils.py:101, in get_base_model_class(model_name, is_classification)
#      98     if model_name == 'MLPReg': return MLPRegressor
#      99     if model_name == 'SGD': return SGDRegressor
# --> 101 raise ValueError(f"Modèle non géré: {model_name} (Clas={is_classification})")
#
# ValueError: Modèle non géré: HisGradientBoosting (Clas=True)
