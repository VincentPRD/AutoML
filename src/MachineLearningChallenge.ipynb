# %%
import automl
data_dest="/info/corpus/ChallengeMachineLearning/data_F/"
modele = automl.AutoML()
modele.fit(data_dest)
modele.eval()
print(modele.predict("/info/corpus/ChallengeMachineLearning/data_F/"))
