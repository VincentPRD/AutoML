# %%
import automl
data_dest="/info/corpus/ChallengeMachineLearning/data_A/"
modele = automl.AutoML()
modele.fit(data_dest)
modele.eval()
print(modele.predict("/info/corpus/ChallengeMachineLearning/data_A/"))
# Out:
# --- Démarrage AutoML sur data_A ---
#  -> Format des données : DataFrame
# Tâche détectée : classification_multi-label
# Configuration du Preprocessing...
# Entraînement de RandomForest...
# Entraînement de HistGradientBoosting...
#
# --- Optimisation du meilleur modèle : HistGradientBoosting ---
#
# --- Démarrage de l'optimisation pour le modèle: HistGradientBoosting (50 essais) ---
#   0%|          | 0/50 [00:00<?, ?it/s]
# =============================================
# OPTIMISATION TERMINÉE pour: HistGradientBoosting
# =============================================
# Finalisation du modèle HistGradientBoosting avec les meilleurs paramètres.
# Entraînement de HistGradientBoosting_optimized...
#
# --- Résultats de l'évaluation initiale ---
# Modèle: RandomForest         | Score Global: 0.8695 | Détails: [F1_MACRO: 0.904, JACCARD: 0.835]
# Modèle: HistGradientBoosting | Score Global: 0.8769 | Détails: [F1_MACRO: 0.910, JACCARD: 0.844]
# Modèle: HistGradientBoosting_optimized | Score Global: 0.8756 | Détails: [F1_MACRO: 0.909, JACCARD: 0.842]
#
# MEILLEUR MODÈLE SÉLECTIONNÉ : HistGradientBoosting (Score initial: 0.8769)
#
# --- Prédiction en cours ---
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 modele.fit(data_dest)
#       5 modele.eval()
# ----> 6 print(modele.predict("/info/corpus/ChallengeMachineLearning/data_A/"))
#
# File /info/raid-etu/m1/s2102508/M1/Projet_Methodo/AutoML/src/automl.py:194, in AutoML.predict(self, data_dest)
#     191 print(f"\n--- Prédiction en cours ---")
#     193 if self.best_model_obj is None or self.preprocessor is None:
# --> 194     raise Exception("Le modèle n'est pas entraîné ou le meilleur modèle n'a pas été défini.")
#     196 # 1. Chargement/Préparation des données de prédiction
#     197 df_to_predict = None
#
# Exception: Le modèle n'est pas entraîné ou le meilleur modèle n'a pas été défini.
