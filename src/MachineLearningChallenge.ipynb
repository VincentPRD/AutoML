# %%
import automl
data_dest="/info/corpus/ChallengeMachineLearning/data_B/"
modele = automl.AutoML()
modele.fit(data_dest)
modele.eval()
print(modele.predict("/info/corpus/ChallengeMachineLearning/data_B/"))
# Out:
# --- Démarrage AutoML sur data_B ---
#  -> Format des données : DataFrame
# Tâche détectée : régression
# Configuration du Preprocessing...
# Entraînement de RandomForestReg...
# Entraînement de SGDRegressor...
# Entraînement de HistGradientBoostingReg...
#
# --- Optimisation du meilleur modèle : HistGradientBoostingReg ---
#
# --- Démarrage de l'optimisation pour le modèle: HistGradientBoostingReg (50 essais) ---
#   0%|          | 0/50 [00:00<?, ?it/s]
# =============================================
# OPTIMISATION TERMINÉE pour: HistGradientBoostingReg
# =============================================
# Finalisation du modèle HistGradientBoostingReg avec les meilleurs paramètres.
# Entraînement de HistGradientBoostingReg_optimized...
#
# --- Résultats de l'évaluation initiale ---
# Modèle: RandomForestReg      | Score Global: 0.3381 | Détails: []
# Modèle: SGDRegressor         | Score Global: 0.2980 | Détails: []
# Modèle: HistGradientBoostingReg | Score Global: 0.3663 | Détails: []
# Modèle: HistGradientBoostingReg_optimized | Score Global: 0.3676 | Détails: []
#
# MEILLEUR MODÈLE SÉLECTIONNÉ : HistGradientBoostingReg_optimized (Score initial: 0.3676)
#
# --- Prédiction en cours ---
# [110288.48739173 263087.2550647  118002.59223924 ... 396083.69219255
#  271757.58889955 120704.97567708]
