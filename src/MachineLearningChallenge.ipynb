# %%
import automl
data_dest="/info/corpus/ChallengeMachineLearning/data_C/"
modele = automl.AutoML()
modele.fit(data_dest)
modele.eval()
print(modele.predict("/info/corpus/ChallengeMachineLearning/data_C/"))
# Out:
# --- Démarrage AutoML sur data_C ---
#  -> Format des données : DataFrame
# Tâche détectée : classification_multi-classe
# Configuration du Preprocessing...
# Entraînement de RandomForest...
# Entraînement de LogisticRegression...
# Entraînement de SGD...
# Entraînement de HistGradientBoosting...
# Entraînement de KNN...
#
# --- Résultats de l'évaluation initiale ---
# Modèle: RandomForest         | Score Global: 0.9629 | Détails: [ACCURACY: 0.946, F1_MACRO: 0.945]
# Modèle: LogisticRegression   | Score Global: 0.9051 | Détails: [ACCURACY: 0.867, F1_MACRO: 0.864]
# Modèle: SGD                  | Score Global: 0.8820 | Détails: [ACCURACY: 0.883, F1_MACRO: 0.881]
# Modèle: HistGradientBoosting | Score Global: 0.9645 | Détails: [ACCURACY: 0.948, F1_MACRO: 0.948]
# Modèle: KNN                  | Score Global: 0.9041 | Détails: [ACCURACY: 0.868, F1_MACRO: 0.867]
#
# MEILLEUR MODÈLE SÉLECTIONNÉ : HistGradientBoosting (Score initial: 0.9645)
#
# ...
