# %%
import automl
data_dest="/info/corpus/ChallengeMachineLearning/data_H/"
modele = automl.AutoML()
modele.fit(data_dest)
modele.eval()
print(modele.predict("/info/corpus/ChallengeMachineLearning/data_H/"))
# Out:
# --- Démarrage AutoML sur data_H ---
#  -> Format détecté : Sparse Matrix (LibSVM)
#     -> Détection : Format sans colonne cible (Label). Chargement adapté...
# Tâche détectée : classification_multi-label (Données creuses: True)
# Configuration du Preprocessing...
#  -> Preprocessing mode Sparse activé.
# Entraînement de RandomForest...
# Entraînement de MLP...
# /info/etu/m1/s2102508/miniconda3/envs/Methodo/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:788: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# --- Résultats de l'évaluation ---
# Modèle: RandomForest         | Score: 0.2222 | Détails: f1_macro= 0.200, jaccard= 0.245
# Modèle: MLP                  | Score: 0.4788 | Détails: f1_macro= 0.477, jaccard= 0.480
#
# MEILLEUR MODÈLE : MLP (Score: 0.4788)
#
# --- Prédiction en cours ---
#  -> Format détecté : Sparse Matrix (LibSVM)
# ...
