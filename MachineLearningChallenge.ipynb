# %%
import automl
data_dest="data_G"
modele = automl.AutoML()
modele.fit(data_dest)
modele.eval()
# Out:
# Il s'agit d'un problème de classification binaire !
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.90      0.93       770
#          1.0       0.91      0.97      0.94       768
#
#     accuracy                           0.93      1538
#    macro avg       0.94      0.93      0.93      1538
# weighted avg       0.94      0.93      0.93      1538
#
# Accuracy : 0.9336801040312094
