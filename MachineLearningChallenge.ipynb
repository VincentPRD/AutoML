# %%
import automl
data_dest="data_A"
modele = automl.AutoML()
modele.fit(data_dest)
modele.eval()
# Out:
# Il s'agit d'un problème de classification multilabels !
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93      7118
#            1       0.89      0.87      0.88      5620
#            2       0.87      0.94      0.90      6265
#
#    micro avg       0.88      0.94      0.91     19003
#    macro avg       0.88      0.94      0.91     19003
# weighted avg       0.88      0.94      0.91     19003
#  samples avg       0.88      0.94      0.89     19003
#
# Accuracy : 0.6103739445114595
